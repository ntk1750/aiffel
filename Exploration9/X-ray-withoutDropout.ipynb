# %% [markdown]
# ### 패키지 import

# %%
import os, re
import random, math
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ### 데이터 load하기

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE
# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# 데이터 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')
TRAIN_PATH = ROOT_PATH + '/chest_xray/data/train/*/*' # *은 모든 디렉토리와 파일을 의미합니다.
VAL_PATH = ROOT_PATH + '/chest_xray/data/val/*/*'
TEST_PATH = ROOT_PATH + '/chest_xray/data/test/*/*'

BATCH_SIZE = 32#16
EPOCHS = 25

print(ROOT_PATH)
# Out:
# /aiffel/aiffel

# %% [markdown]
# #### batch size

# %% [markdown]
# batch size란 머신러닝 데이터를 학습하는 과정에서 최적화(gradient descent)할 때 한번에 몇개의 데이터를 가지고 하는지를 나타냄

# %% [markdown]
# batch size는 데이터가 엄청나게 많은 경우 전체 데이터를 보고 최적화를 할 때 엄청난 시간이 할애할 수 있음
# <br/>
# 그래서 정확도는 좀 떨어져도 batch size를 줄여 시간을 단축시킬 수 있음

# %% [markdown]
# ### 데이터 확인하기

# %%
train_filenames = tf.io.gfile.glob(TRAIN_PATH)
test_filenames = tf.io.gfile.glob(TEST_PATH)
val_filenames = tf.io.gfile.glob(VAL_PATH)

print(len(train_filenames))
print(len(test_filenames))
print(len(val_filenames))
# Out:
# 5216
# 624
# 16

# %% [markdown]
# #### validation 갯수가 너무 작아 train 데이터와 합쳐서 8:2로 다시 분할

# %%
# train 데이터와 validation 데이터를 모두 filenames에 담습니다
filenames = tf.io.gfile.glob(TRAIN_PATH)
filenames.extend(tf.io.gfile.glob(VAL_PATH))

# 모아진 filenames를 8:2로 나눕니다
train_size = math.floor(len(filenames)*0.8)
random.seed(8)
random.shuffle(filenames)
train_filenames = filenames[:train_size]
val_filenames = filenames[train_size:]

print(len(train_filenames))
print(len(val_filenames))
# Out:
# 4185
# 1047

# %% [markdown]
# ### 정상 이미지와 폐렴 이미지 구분하기

# %%
print(f'Normal image path\n{filenames[0]}')
print(f'Pneumonia image path\n{filenames[2000]}')
# Out:
# Normal image path
# /aiffel/aiffel/chest_xray/data/train/NORMAL/NORMAL2-IM-1317-0001.jpeg
# Pneumonia image path
# /aiffel/aiffel/chest_xray/data/train/PNEUMONIA/person299_bacteria_1418.jpeg

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print(f"Normal images count in training set: {COUNT_NORMAL}")


COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print(f"Pneumonia images count in training set: {COUNT_PNEUMONIA}")
# Out:
# Normal images count in training set: 1070
# Pneumonia images count in training set: 3115

# %% [markdown]
# ### tf.data 인스턴스 만들기

# %% [markdown]
# tensorflow에 학습시킬 때 mini-batch로 작업할 수 있음

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print(f"Training images count: {TRAIN_IMG_COUNT}")

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print(f"Validating images count: {VAL_IMG_COUNT}")
# Out:
# Training images count: 4185
# Validating images count: 1047

# %% [markdown]
# ### 라벨 생성하기

# %% [markdown]
# 이미지 라벨 데이터가 따로 없으므로 파일 경로에 따라 라벨 데이터 생성

# %%
# 파일 경로의 끝에서 두번째 부분을 확인하면 양성과 음성을 구분할 수 있습니다
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)

# %% [markdown]
# ### 이미지 데이터 사이즈 통일

# %% [markdown]
# 현실적인 이미지 데이터는 사이즈가 제각각일 가능성이 높기 때문에 이미지의 사이즈를 통일함
# <br/>
# GPU 메모리를 효율적으로 사용할 수 있음

# %%
# 이미지를 알맞은 형식으로 바꿉니다.
def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3) # 이미지를 uint8 tensor로 수정
    img = tf.image.convert_image_dtype(img, tf.float32) # float32 타입으로 수정
    img = tf.image.resize(img, IMAGE_SIZE) # 이미지 사이즈를 IMAGE_SIZE로 수정
    return img

# 이미지 파일의 경로를 입력하면 이미지와 라벨을 읽어옵니다.
def process_path(file_path):
    label = get_label(file_path) # 라벨 검출
    img = tf.io.read_file(file_path) # 이미지 읽기
    img = decode_img(img) # 이미지를 알맞은 형식으로 수정
    return img, label

# %%
# 이미지를 알맞은 형식으로 바꿉니다.
def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3) # 이미지를 uint8 tensor로 수정
    img = tf.image.convert_image_dtype(img, tf.float32) # float32 타입으로 수정
    img = tf.image.resize(img, IMAGE_SIZE) # 이미지 사이즈를 IMAGE_SIZE로 수정
    return img

# 이미지 파일의 경로를 입력하면 이미지와 라벨을 읽어옵니다.
def process_path(file_path):
    label = get_label(file_path) # 라벨 검출
    img = tf.io.read_file(file_path) # 이미지 읽기
    img = decode_img(img) # 이미지를 알맞은 형식으로 수정
    return img, label

# %% [markdown]
# ### 데이터셋 생성

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in train_ds.take(1): #train_ds.take(1): 데이터 1개만 가져옴
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  False

# %%
test_list_ds = tf.data.Dataset.list_files(TEST_PATH)
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 624

# %% [markdown]
# ### 학습을 위한 데이터 가져오기

# %%
def prepare_for_training(ds, shuffle_buffer_size=1000):
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat()
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    return ds

# %%
train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %% [markdown]
# ### 데이터 시각화

# %%
# 이미지 배치를 입력하면 여러장의 이미지를 보여줍니다.
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(BATCH_SIZE):
        ax = plt.subplot(4,math.ceil(BATCH_SIZE/4),n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")


image_batch, label_batch = next(iter(train_ds))
show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# ### CNN 모델링

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ])
    
    return block

# %%
# def dense_block(units, dropout_rate):
#     block = tf.keras.Sequential([
#         tf.keras.layers.Dense(units, activation='relu'),
#         tf.keras.layers.BatchNormalization(),
#         tf.keras.layers.Dropout(dropout_rate)
#     ])
    
#     return block

# %%
def dense_block(units):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
    ])
    
    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
#         dense_block(512, 0.7),
#         dense_block(128, 0.5),
#         dense_block(64, 0.3),
        dense_block(512),
        dense_block(128),
        dense_block(64),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %% [markdown]
# ### 데이터 imbalance 처리하기

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for NORMAL: {:.2f}'.format(weight_for_0))
print('Weight for PNEUMONIA: {:.2f}'.format(weight_for_1))
# Out:
# Weight for NORMAL: 1.96
# Weight for PNEUMONIA: 0.67

# %% [markdown]
# weight balancing
# <br/>
# training set의 각 데이터에서 loss를 계산할 때 특정 클래스의 데이터에 큰 loss 값을 갖도록 하는 방법

# %% [markdown]
# weight는 normal과 Pneumonia 전체 데이터 건수에 반비례하도록 설정

# %% [markdown]
# ### 모델 훈련하기

# %%
with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/25
# 130/130 [==============================] - 38s 224ms/step - loss: 0.3294 - accuracy: 0.8399 - precision: 0.9601 - recall: 0.8198 - val_loss: 0.5618 - val_accuracy: 0.7520 - val_precision: 0.7520 - val_recall: 1.0000
# Epoch 2/25
# 130/130 [==============================] - 28s 218ms/step - loss: 0.2254 - accuracy: 0.9106 - precision: 0.9676 - recall: 0.9099 - val_loss: 0.6491 - val_accuracy: 0.7051 - val_precision: 0.7051 - val_recall: 1.0000
# Epoch 3/25
# 130/130 [==============================] - 29s 221ms/step - loss: 0.1750 - accuracy: 0.9337 - precision: 0.9764 - recall: 0.9337 - val_loss: 0.9661 - val_accuracy: 0.7402 - val_precision: 0.7402 - val_recall: 1.0000
# Epoch 4/25
# 130/130 [==============================] - 30s 229ms/step - loss: 0.1760 - accuracy: 0.9380 - precision: 0.9797 - recall: 0.9360 - val_loss: 0.9856 - val_accuracy: 0.7559 - val_precision: 0.7559 - val_recall: 1.0000
# Epoch 5/25
# ...

# %% [markdown]
# ### 모델결과확인하기

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ### loss, accuracy, precision, recall 값 확인

# %%
loss, accuracy, precision, recall = model.evaluate(test_ds)
print(f'Loss: {loss},\nAccuracy: {accuracy},\nPrecision: {precision},\nRecall: {recall}')
# Out:
# 39/39 [==============================] - 4s 113ms/step - loss: 0.4986 - accuracy: 0.8830 - precision: 0.8729 - recall: 0.9513
# Loss: 0.4985578954219818,
# Accuracy: 0.8830128312110901,
# Precision: 0.8729411959648132,
# Recall: 0.9512820243835449

# %% [markdown]
# ### 각 모델 구성에 따른 모델 학습 결과 비교 분석

# %% [markdown]
# #### data augmentation 적용 결과

# %%
from IPython.display import Image

# %%
path = os.getenv('HOME') + "/aiffel/chest_xray/dataAugmentation.png"
Image(path)

# %%
path = os.getenv('HOME') + "/aiffel/chest_xray/data_result.png"
Image(path)

# %% [markdown]
# #### dropout 제거 후 실행 결과

# %%
path = os.getenv('HOME') + "/aiffel/chest_xray/dropout.png"
Image(path)

# %%
path = os.getenv('HOME') + "/aiffel/chest_xray/dropout_result.png"
Image(path)

# %% [markdown]
# #### data augmentation과 dropout 결과 분석

# %% [markdown]
# data augmentation과 dropout 결과를 확인해보면 data augmentation에서는 각 acc: 0.86, recall: 0.94, dropout에서는 acc: 0.88 recall: 0.95의 결과가 나왔다.
# data augmentation만으로도 acc가 85%넘을 수 있도록 성능을 개선되었지만 dropout 부분을 제거한 후 실행한 결과 전반적으로 정확도와 recall 성능이 더욱 향상된 것으로 나타났다.
# <br/>

# %% [markdown]
# 또한, 결과 그래프를 확인해보면 data augmentation과 dropout 뺀 모델의 결과 그래프를 비교해보면 val data의 모습에서 차이를 볼 수 있다.
# <br/>
# val 값의 변동이 자주 나타날수록 해당 모델의 정확도와 일반화가 원활하게 이루어지지 않는 모델로 판단된다.
# <br/>
# (val 값이 올라갈수록 모델의 일반화 Good, val 값이 내려가면 train data에만 overfitting)

# %% [markdown]
# data augmentation에서는 전반적으로 val data에 대한 성능 변화가 많은 반면 dropout을 제거한 model에서는 val data 들쑥날쑥한 부분도 있지만 data augmentation보다 적다는 것을 볼 수 있다.

# %% [markdown]
# 기존의 CNN 모델에서 일반적인 CNN과 달리 batch normalization과 dropout을 모두 적용한 모델을 구성하였다. 하지만 batch normalization만으로도 어느 정도의 성능에 맞는 regularization 효과를 낼 수 있다.
# <br/>
# 오히러 많은 regularization는 학습에 필요한 feature을 제거하고 학습을 진행하여 오히려 성능을 떨어뜨릴 수 있기 때문에 주의하면 사용해야 한다는 것을 이번 과제를 통해 알게되었다.

# %% [markdown]
# #### learning rate 변경 후 실행 결과

# %%
path = os.getenv('HOME') + "/aiffel/chest_xray/learningrate.png"
Image(path)

# %%
path = os.getenv('HOME') + "/aiffel/chest_xray/learningrate_result.png"
Image(path)

# %% [markdown]
# data augmentation과 dropout 제거에서 그치지 않고 learning rate를 변경하여 학습을 진행하였다.<br/>
# 하지만 learning rate를 0.01로 변경 후 학습한 결과 dropout 제거된 모델보다 정확도나 recall 성능이 떨어지는 결과가 나타났으며 결과 그래프를 보아도 val data의 변화가 이전 모델에 비해 변동되는 현상이 많이 일어나고 있다는 것을 확인할 수 있었다.

# %% [markdown]
# learning rate의 경우 조금만 커져도 최적값에 도달하는 step이 커져 최적값에 가까워 졌다가 지나가는 경우가 발생하기 때문에 신중하게 변경해야한다는 것을 이번 모델 학습을 통해 알게 되었다.

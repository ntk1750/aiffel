# %% [markdown]
# ### 패키지 import

# %%
import os, re
import random, math
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ### 데이터 load하기

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE
# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# 데이터 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')
TRAIN_PATH = ROOT_PATH + '/chest_xray/data/train/*/*' # *은 모든 디렉토리와 파일을 의미합니다.
VAL_PATH = ROOT_PATH + '/chest_xray/data/val/*/*'
TEST_PATH = ROOT_PATH + '/chest_xray/data/test/*/*'

BATCH_SIZE = 32#16
EPOCHS = 25

print(ROOT_PATH)
# Out:
# /aiffel/aiffel

# %% [markdown]
# #### batch size

# %% [markdown]
# batch size란 머신러닝 데이터를 학습하는 과정에서 최적화(gradient descent)할 때 한번에 몇개의 데이터를 가지고 하는지를 나타냄

# %% [markdown]
# batch size는 데이터가 엄청나게 많은 경우 전체 데이터를 보고 최적화를 할 때 엄청난 시간이 할애할 수 있음
# <br/>
# 그래서 정확도는 좀 떨어져도 batch size를 줄여 시간을 단축시킬 수 있음

# %% [markdown]
# ### 데이터 확인하기

# %%
train_filenames = tf.io.gfile.glob(TRAIN_PATH)
test_filenames = tf.io.gfile.glob(TEST_PATH)
val_filenames = tf.io.gfile.glob(VAL_PATH)

print(len(train_filenames))
print(len(test_filenames))
print(len(val_filenames))
# Out:
# 5216
# 624
# 16

# %% [markdown]
# #### validation 갯수가 너무 작아 train 데이터와 합쳐서 8:2로 다시 분할

# %%
# train 데이터와 validation 데이터를 모두 filenames에 담습니다
filenames = tf.io.gfile.glob(TRAIN_PATH)
filenames.extend(tf.io.gfile.glob(VAL_PATH))

# 모아진 filenames를 8:2로 나눕니다
train_size = math.floor(len(filenames)*0.8)
random.seed(8)
random.shuffle(filenames)
train_filenames = filenames[:train_size]
val_filenames = filenames[train_size:]

print(len(train_filenames))
print(len(val_filenames))
# Out:
# 4185
# 1047

# %% [markdown]
# ### 정상 이미지와 폐렴 이미지 구분하기

# %%
print(f'Normal image path\n{filenames[0]}')
print(f'Pneumonia image path\n{filenames[2000]}')
# Out:
# Normal image path
# /aiffel/aiffel/chest_xray/data/train/NORMAL/NORMAL2-IM-1317-0001.jpeg
# Pneumonia image path
# /aiffel/aiffel/chest_xray/data/train/PNEUMONIA/person299_bacteria_1418.jpeg

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print(f"Normal images count in training set: {COUNT_NORMAL}")


COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print(f"Pneumonia images count in training set: {COUNT_PNEUMONIA}")
# Out:
# Normal images count in training set: 1072
# Pneumonia images count in training set: 3113

# %% [markdown]
# ### tf.data 인스턴스 만들기

# %% [markdown]
# tensorflow에 학습시킬 때 mini-batch로 작업할 수 있음

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print(f"Training images count: {TRAIN_IMG_COUNT}")

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print(f"Validating images count: {VAL_IMG_COUNT}")
# Out:
# Training images count: 4185
# Validating images count: 1047

# %% [markdown]
# ### 라벨 생성하기

# %% [markdown]
# 이미지 라벨 데이터가 따로 없으므로 파일 경로에 따라 라벨 데이터 생성

# %%
# 파일 경로의 끝에서 두번째 부분을 확인하면 양성과 음성을 구분할 수 있습니다
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)

# %% [markdown]
# ### 이미지 데이터 사이즈 통일

# %% [markdown]
# 현실적인 이미지 데이터는 사이즈가 제각각일 가능성이 높기 때문에 이미지의 사이즈를 통일함
# <br/>
# GPU 메모리를 효율적으로 사용할 수 있음

# %%
# 이미지를 알맞은 형식으로 바꿉니다.
def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3) # 이미지를 uint8 tensor로 수정
    img = tf.image.convert_image_dtype(img, tf.float32) # float32 타입으로 수정
    img = tf.image.resize(img, IMAGE_SIZE) # 이미지 사이즈를 IMAGE_SIZE로 수정
    return img

# 이미지 파일의 경로를 입력하면 이미지와 라벨을 읽어옵니다.
def process_path(file_path):
    label = get_label(file_path) # 라벨 검출
    img = tf.io.read_file(file_path) # 이미지 읽기
    img = decode_img(img) # 이미지를 알맞은 형식으로 수정
    return img, label

# %%
# 이미지를 알맞은 형식으로 바꿉니다.
def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3) # 이미지를 uint8 tensor로 수정
    img = tf.image.convert_image_dtype(img, tf.float32) # float32 타입으로 수정
    img = tf.image.resize(img, IMAGE_SIZE) # 이미지 사이즈를 IMAGE_SIZE로 수정
    return img

# 이미지 파일의 경로를 입력하면 이미지와 라벨을 읽어옵니다.
def process_path(file_path):
    label = get_label(file_path) # 라벨 검출
    img = tf.io.read_file(file_path) # 이미지 읽기
    img = decode_img(img) # 이미지를 알맞은 형식으로 수정
    return img, label

# %% [markdown]
# ### 데이터셋 생성

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in train_ds.take(1): #train_ds.take(1): 데이터 1개만 가져옴
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  False

# %%
test_list_ds = tf.data.Dataset.list_files(TEST_PATH)
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 624

# %% [markdown]
# ### 학습을 위한 데이터 가져오기

# %% [markdown]
# #### 좌우반전 Data augmentation

# %% [markdown]
# #### Data augmentation

# %% [markdown]
# 데이터 양을 늘리기 위해 원본에 각종 변환을 적용해서 개수를 증강시키는 방법
# <br/>
# Pixel-Level transforms, spatial-level trainforms 등이 있음
# <br/>
# https://hoya012.github.io/blog/Image-Data-Augmentation-Overview/

# %%
def augment(image,label):
    image = tf.image.random_flip_left_right(image)  # 랜덤하게 좌우를 반전합니다.
    return image,label

# %% [markdown]
# 이미지 데이터 좌우를 바꿔 이미지를 추가하는 방법

# %%
def prepare_for_training(ds, shuffle_buffer_size=1000):
    # augment 적용 부분이 배치처리 함수에 추가되었습니다.
    ds = ds.map(
            augment,       # augment 함수 적용
            num_parallel_calls=2
        )
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat()
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

# %%
train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %% [markdown]
# ### 데이터 시각화

# %%
# 이미지 배치를 입력하면 여러장의 이미지를 보여줍니다.
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(BATCH_SIZE):
        ax = plt.subplot(4,math.ceil(BATCH_SIZE/4),n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")


image_batch, label_batch = next(iter(train_ds))
show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# ### CNN 모델링

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ])
    
    return block

# %%
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %% [markdown]
# ### 데이터 imbalance 처리하기

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for NORMAL: {:.2f}'.format(weight_for_0))
print('Weight for PNEUMONIA: {:.2f}'.format(weight_for_1))
# Out:
# Weight for NORMAL: 1.95
# Weight for PNEUMONIA: 0.67

# %% [markdown]
# weight balancing
# <br/>
# training set의 각 데이터에서 loss를 계산할 때 특정 클래스의 데이터에 큰 loss 값을 갖도록 하는 방법

# %% [markdown]
# weight는 normal과 Pneumonia 전체 데이터 건수에 반비례하도록 설정

# %% [markdown]
# ### 모델 훈련하기

# %%
with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/25
# 130/130 [==============================] - 38s 222ms/step - loss: 0.5488 - accuracy: 0.6995 - precision: 0.9230 - recall: 0.6536 - val_loss: 0.6172 - val_accuracy: 0.7266 - val_precision: 0.7266 - val_recall: 1.0000
# Epoch 2/25
# 130/130 [==============================] - 29s 223ms/step - loss: 0.2676 - accuracy: 0.8841 - precision: 0.9751 - recall: 0.8652 - val_loss: 0.6461 - val_accuracy: 0.7285 - val_precision: 0.7285 - val_recall: 1.0000
# Epoch 3/25
# 130/130 [==============================] - 29s 223ms/step - loss: 0.2695 - accuracy: 0.8942 - precision: 0.9660 - recall: 0.8907 - val_loss: 0.6633 - val_accuracy: 0.7520 - val_precision: 0.7520 - val_recall: 1.0000
# Epoch 4/25
# 130/130 [==============================] - 30s 228ms/step - loss: 0.2079 - accuracy: 0.9149 - precision: 0.9802 - recall: 0.9028 - val_loss: 1.0307 - val_accuracy: 0.7363 - val_precision: 0.7363 - val_recall: 1.0000
# Epoch 5/25
# 130/130 [==============================] - 30s 232ms/step - loss: 0.2343 - accuracy: 0.9130 - precision: 0.9740 - recall: 0.9088 - val_loss: 0.7758 - val_accuracy: 0.7324 - val_precision: 0.7324 - val_recall: 1.0000
# Epoch 6/25
# 130/130 [==============================] - 31s 243ms/step - loss: 0.2041 - accuracy: 0.9260 - precision: 0.9758 - recall: 0.9221 - val_loss: 0.4175 - val_accuracy: 0.7871 - val_precision: 0.7715 - val_recall: 1.0000
# Epoch 7/25
# 130/130 [==============================] - 32s 244ms/step - loss: 0.1905 - accuracy: 0.9255 - precision: 0.9779 - recall: 0.9200 - val_loss: 0.2994 - val_accuracy: 0.8516 - val_precision: 0.8333 - val_recall: 1.0000
# Epoch 8/25
# 130/130 [==============================] - 30s 232ms/step - loss: 0.1717 - accuracy: 0.9346 - precision: 0.9823 - recall: 0.9291 - val_loss: 0.0645 - val_accuracy: 0.9766 - val_precision: 0.9762 - val_recall: 0.9919
# Epoch 9/25
# 130/130 [==============================] - 28s 215ms/step - loss: 0.1696 - accuracy: 0.9356 - precision: 0.9797 - recall: 0.9330 - val_loss: 0.0857 - val_accuracy: 0.9746 - val_precision: 0.9833 - val_recall: 0.9806
# Epoch 10/25
# 130/130 [==============================] - 27s 212ms/step - loss: 0.1867 - accuracy: 0.9250 - precision: 0.9766 - recall: 0.9207 - val_loss: 0.1462 - val_accuracy: 0.9355 - val_precision: 0.9263 - val_recall: 0.9921
# Epoch 11/25
# 130/130 [==============================] - 28s 215ms/step - loss: 0.1878 - accuracy: 0.9341 - precision: 0.9718 - recall: 0.9383 - val_loss: 0.1307 - val_accuracy: 0.9590 - val_precision: 0.9944 - val_recall: 0.9488
# Epoch 12/25
# 130/130 [==============================] - 27s 209ms/step - loss: 0.1558 - accuracy: 0.9385 - precision: 0.9837 - recall: 0.9329 - val_loss: 0.0933 - val_accuracy: 0.9688 - val_precision: 0.9945 - val_recall: 0.9626
# Epoch 13/25
# 130/130 [==============================] - 28s 216ms/step - loss: 0.1561 - accuracy: 0.9389 - precision: 0.9791 - recall: 0.9379 - val_loss: 0.1174 - val_accuracy: 0.9551 - val_precision: 0.9944 - val_recall: 0.9437
# Epoch 14/25
# 130/130 [==============================] - 28s 216ms/step - loss: 0.1784 - accuracy: 0.9322 - precision: 0.9797 - recall: 0.9287 - val_loss: 0.2678 - val_accuracy: 0.9102 - val_precision: 1.0000 - val_recall: 0.8789
# Epoch 15/25
# 130/130 [==============================] - 28s 215ms/step - loss: 0.1573 - accuracy: 0.9409 - precision: 0.9857 - recall: 0.9342 - val_loss: 0.2498 - val_accuracy: 0.8926 - val_precision: 1.0000 - val_recall: 0.8556
# Epoch 16/25
# 130/130 [==============================] - 27s 212ms/step - loss: 0.1219 - accuracy: 0.9490 - precision: 0.9891 - recall: 0.9417 - val_loss: 0.1256 - val_accuracy: 0.9531 - val_precision: 0.9398 - val_recall: 1.0000
# Epoch 17/25
# 130/130 [==============================] - 28s 216ms/step - loss: 0.1811 - accuracy: 0.9346 - precision: 0.9760 - recall: 0.9360 - val_loss: 0.1021 - val_accuracy: 0.9629 - val_precision: 1.0000 - val_recall: 0.9500
# Epoch 18/25
# 130/130 [==============================] - 28s 213ms/step - loss: 0.1233 - accuracy: 0.9553 - precision: 0.9871 - recall: 0.9517 - val_loss: 0.1528 - val_accuracy: 0.9434 - val_precision: 1.0000 - val_recall: 0.9223
# Epoch 19/25
# 130/130 [==============================] - 28s 215ms/step - loss: 0.1476 - accuracy: 0.9466 - precision: 0.9852 - recall: 0.9429 - val_loss: 0.1411 - val_accuracy: 0.9473 - val_precision: 0.9973 - val_recall: 0.9342
# Epoch 20/25
# 130/130 [==============================] - 28s 214ms/step - loss: 0.1581 - accuracy: 0.9394 - precision: 0.9774 - recall: 0.9389 - val_loss: 0.1507 - val_accuracy: 0.9336 - val_precision: 0.9971 - val_recall: 0.9113
# Epoch 21/25
# 130/130 [==============================] - 28s 218ms/step - loss: 0.1390 - accuracy: 0.9394 - precision: 0.9833 - recall: 0.9359 - val_loss: 0.1348 - val_accuracy: 0.9512 - val_precision: 0.9972 - val_recall: 0.9378
# Epoch 22/25
# 130/130 [==============================] - 28s 217ms/step - loss: 0.1605 - accuracy: 0.9394 - precision: 0.9815 - recall: 0.9355 - val_loss: 0.0750 - val_accuracy: 0.9688 - val_precision: 0.9945 - val_recall: 0.9628
# Epoch 23/25
# 130/130 [==============================] - 28s 218ms/step - loss: 0.1139 - accuracy: 0.9529 - precision: 0.9879 - recall: 0.9484 - val_loss: 0.3760 - val_accuracy: 0.8828 - val_precision: 1.0000 - val_recall: 0.8408
# Epoch 24/25
# 130/130 [==============================] - 28s 213ms/step - loss: 0.1195 - accuracy: 0.9481 - precision: 0.9864 - recall: 0.9429 - val_loss: 0.0494 - val_accuracy: 0.9805 - val_precision: 0.9947 - val_recall: 0.9791
# Epoch 25/25
# 130/130 [==============================] - 28s 218ms/step - loss: 0.1377 - accuracy: 0.9505 - precision: 0.9815 - recall: 0.9519 - val_loss: 0.2323 - val_accuracy: 0.9062 - val_precision: 1.0000 - val_recall: 0.8747

# %% [markdown]
# ### 결과확인하기

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ### loss, accuracy, precision, recall 값 확인

# %%
loss, accuracy, precision, recall = model.evaluate(test_ds)
print(f'Loss: {loss},\nAccuracy: {accuracy},\nPrecision: {precision},\nRecall: {recall}')
# Out:
# 39/39 [==============================] - 5s 114ms/step - loss: 0.3796 - accuracy: 0.8654 - precision: 0.8558 - recall: 0.9436
# Loss: 0.3796401023864746,
# Accuracy: 0.8653846383094788,
# Precision: 0.8558139801025391,
# Recall: 0.9435897469520569

# %% [markdown]
# #### 최종 결과 비교 dropout에서 확인
